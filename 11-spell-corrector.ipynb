# %%
import re
from collections import Counter

# %%
# function to tokenise words
def words(document):
    "Convert text to lower case and tokenise the document"
    return re.findall(r'\w+', document.lower())

# %%
# create a frequency table of all the words of the document
all_words = Counter(words(open('/mnt/d/6- Books/upgrad/TextMining/big.txt').read()))

# %%
# check frequency of a random word, say, 'chair'
all_words['chair']
# Out:
# 135

# %%
all_words
# Out:
# Counter({'unconciousness': 1,
#          'roseola': 1,
#          'fetes': 2,
#          'combatted': 1,
#          'horses': 262,
#          'differed': 10,
#          'hillside': 2,
#          'his': 10034,
#          'tariff': 123,
#          'fulfilled': 21,
#          'thud': 10,
#          'snugly': 1,
#          'introduce': 23,
#          'division': 110,
#          'utilise': 1,
#          'boxes': 16,
#          'dignitaries': 2,
#          'sterne': 1,
#          'anaphylactic': 1,
#          'afloat': 2,
#          'consultant': 1,
#          '_endarteritis': 1,
#          'annoyance': 18,
#          'beaming': 19,
#          'newly': 39,
#          'heights': 23,
#          'sowing': 6,
#          'cleveland': 42,
#          'purchaser': 4,
#          'sojourn': 3,
#          'chemist': 3,
#          'nausea': 4,
#          'imagines': 4,
#          'enfant': 2,
#          'weeden': 2,
#          'fails': 20,
#          'produces': 23,
#          'portmanteaus': 4,
#          'paragraphs': 10,
#          'arts': 17,
#          'yale': 4,
#          'best': 268,
#          'instantaneously': 4,
#          'mainspring': 2,
#          '_scorbutic': 1,
#          'orthotonos': 1,
#          'presenting': 16,
#          'suggestions': 7,
#          'wielder': 2,
#          'thursday': 7,
#          'lifeless': 12,
#          'majesty': 102,
#          'continents': 3,
#          'scandal': 19,
#          'kazan': 6,
#          'blazing': 7,
#          'our': 1065,
#          'lent': 21,
#          'regards': 16,
#          'which': 4842,
#          'portion': 122,
#          '1644': 1,
#          'pon': 3,
#          'spoiled': 18,
#          'elongated': 8,
#          'suspend': 6,
#          'illusory': 3,
#          'daily': 44,
#          'progressed': 2,
#          'saliva': 8,
#          '455': 4,
#          'lookout': 7,
#          'aspirating': 1,
#          'stromilova': 1,
#          'osseous': 20,
#          'baked': 5,
#          '_vindication': 1,
#          'circumstance': 7,
#          'wheeling': 4,
#          'inherited': 50,
#          'corset': 1,
#          'viennese': 3,
#          'niches': 1,
#          'easterly': 1,
#          'sleepy': 20,
#          'arrivals': 7,
#          'bases': 5,
#          'sadder': 2,
#          'fibrosum': 4,
#          'dependents': 3,
#          'fibrils': 1,
#          'clever': 56,
#          'flabby': 5,
#          'revoir': 11,
#          'ahead': 43,
#          'inhale': 1,
#          'grated': 2,
#          'pedantically': 1,
#          'gargle': 1,
#          'officially': 9,
#          '_cheilotomy_': 1,
#          'cheeks': 47,
#          'crude': 5,
#          'blasting': 1,
#          'lance': 2,
#          'gouge': 6,
#          'habit': 55,
#          'andy': 1,
#          'theatrically': 1,
#          'cordial': 12,
#          'scraped': 21,
#          'paddington': 7,
#          'gantlet': 2,
#          'egg': 14,
#          '1800': 8,
#          'marshals': 26,
#          '_sphagnum': 1,
#          'subdivision': 3,
#          'dissent': 8,
#          '_medullary': 1,
#          'expectancy': 3,
#          '_neurolysis_': 1,
#          'purchasing': 4,
#          'incompatible': 2,
#          'hearken': 1,
#          'ranches': 4,
#          'dmitri': 13,
#          'len': 4,
#          'revolutionists': 7,
#          'seat': 170,
#          'enlarges': 2,
#          '591': 7,
#          'clefts': 3,
#          'derogates': 1,
#          'faire_': 1,
#          'zealously': 3,
#          'memory': 55,
#          '141': 9,
#          'sharpest': 2,
#          'jail': 9,
#          'zest': 3,
#          'lodgings': 11,
#          'personage': 16,
#          'buffalo': 12,
#          'immoral': 3,
#          'punctate': 2,
#          'mortgaged': 2,
#          'geographical': 9,
#          '_cartier': 1,
#          'unequaled': 1,
#          'malcontents': 1,
#          'curves': 4,
#          'eugene': 6,
#          '_reaction_': 1,
#          'fulfil': 3,
#          'erroneous': 7,
#          'salon': 9,
#          'list': 48,
#          'norman': 1,
#          'authorise': 1,
#          'programme': 3,
#          'joined': 76,
#          'thirties': 2,
#          'patte': 1,
#          'stealth': 1,
#          '_emergency': 1,
#          'sailing': 13,
#          'out': 1987,
#          'expert': 7,
#          'must': 955,
#          'separating': 14,
#          'complacent': 4,
#          'submission': 20,
#          'wreaths': 3,
#          'pavlovich': 4,
#          'strenuous': 8,
#          '_opisthotonos_': 1,
#          'warman': 1,
#          'syme': 3,
#          'drifted': 5,
#          'disabling': 1,
#          'enzyme': 1,
#          'miners': 19,
#          'losing': 43,
#          'chlorine': 3,
#          'confines': 3,
#          'shipyards': 2,
#          'memento': 2,
#          'dorsales': 1,
#          'stepmothers': 1,
#          'useless': 48,
#          'miscarriage': 2,
#          'victory': 131,
#          'romantic': 11,
#          'filarial': 4,
#          'swindling': 2,
#          'furtively': 2,
#          'infiltration_': 1,
#          'conclude': 9,
#          'scrutiny': 9,
#          'contractor': 2,
#          'armory': 1,
#          'recurs': 8,
#          'embodied': 3,
#          'chains': 14,
#          '1807': 18,
#          'intangible': 4,
#          'scoundrel': 25,
#          'trying': 181,
#          'clutches': 4,
#          '556': 3,
#          'vanquished': 10,
#          'opacities': 2,
#          'graduated': 6,
#          'corpulent': 2,
#          'shrouded': 2,
#          'islands': 33,
#          'campstool': 3,
#          'spirit': 167,
#          'prints': 2,
#          'usurpation': 1,
#          'pleased': 95,
#          'dover': 3,
#          'furniture': 26,
#          'fist': 8,
#          'rug': 10,
#          'muff': 1,
#          'contests': 10,
#          'hump': 1,
#          'perpetually': 1,
#          'rustan': 1,
#          'angered': 5,
#          'imprisoned': 12,
#          'incubation_': 1,
#          'profit': 24,
#          'thiersch': 4,
#          '_ischaemia_': 1,
#          'searching': 31,
#          'ogg': 21,
#          'softer': 10,
#          'toying': 2,
#          '518': 11,
#          'companions': 18,
#          'anarchical': 1,
#          'epiphysis': 19,
#          'insane': 18,
#          'circumvented': 2,
#          '346': 7,
#          'neonatorum_': 2,
#          'relics': 8,
#          'pursued': 33,
#          'serene': 39,
#          'genus': 1,
#          'unwanted': 1,
#          'deane': 4,
#          'about': 1497,
#          '_derma': 1,
#          'ureters': 2,
#          'slight': 114,
#          'equestrian': 1,
#          'top': 42,
#          'weaving': 6,
#          'reflex': 7,
#          'roll': 26,
#          'cet': 1,
#          'valiant': 8,
#          'gladdening': 2,
#          'clergyman': 9,
#          '896': 3,
#          'sail': 8,
#          'venture': 17,
#          'bantering': 2,
#          'pleurosthotonos': 1,
#          'quid': 1,
#          'saltpeter': 2,
#          'relay': 4,
#          'sob': 19,
#          'offshoots': 2,
#          'septique_': 1,
#          'breakfasts': 2,
#          'cooling': 4,
#          'tropical': 9,
#          'recess': 6,
#          '36': 18,
#          'careening': 1,
#          'downy': 8,
#          'laurels': 3,
#          'fleas': 3,
#          'sophie': 5,
#          'affectionate': 23,
#          'disorganization': 1,
#          'quietest': 2,
#          'places': 89,
#          'inappropriately': 1,
#          '_nail': 1,
#          'tornado': 1,
#          'asserted': 12,
#          'bribery': 3,
#          'obtaining': 18,
#          'sparingly': 1,
#          'howard': 4,
#          '_starting': 1,
#          'hume': 2,
#          'jewish': 4,
#          'ancestral': 3,
#          'morning': 337,
#          'mavra': 26,
#          'cruelty': 25,
#          'patron': 4,
#          'thierry': 3,
#          'grouping': 2,
#          'predecessors': 2,
#          'apparelled': 1,
#          '296': 3,
#          'banners': 6,
#          'technically': 2,
#          'awkward': 36,
#          'recognition': 33,
#          'demand': 77,
#          'yuma': 2,
#          'refrigerans': 2,
#          'garfield': 9,
#          'anaesthesia': 23,
#          '239': 14,
#          'unfolded': 5,
#          'inconvenience': 21,
#          'gesture': 60,
#          'man': 1648,
#          'aforesaid': 1,
#          'insidiously': 4,
#          'instruction': 12,
#          'wring': 6,
#          'star': 24,
#          'learn': 38,
#          'aseptically': 1,
#          'picric': 4,
#          'fedchenko': 1,
#          'enucleators': 1,
#          'looming': 2,
#          'ridiculously': 1,
#          'practical': 62,
#          'metamorphosis': 1,
#          'donations': 47,
#          'hygroma': 8,
#          'aden': 1,
#          'nasi': 3,
#          'plunging': 5,
#          'arthur': 34,
#          'bones': 257,
#          'lane': 27,
#          'germinal': 1,
#          'vocational': 3,
#          'philosophize': 1,
#          'transforming': 3,
#          'procrastinator': 1,
#          'lamina': 2,
#          'gowers': 1,
#          '_selected': 1,
#          'attacking': 25,
#          'treachery': 14,
#          'eyeball': 3,
#          'deposes': 1,
#          'capitally': 3,
#          'scandinavia': 3,
#          'delay': 47,
#          'appropriation': 6,
#          'skiagraphy': 3,
#          '1752': 2,
#          'pikestaff': 1,
#          'extravasation': 6,
#          'blot': 2,
#          '611': 5,
#          'surest': 3,
#          'schmidt': 8,
#          '_formation': 3,
#          'fingers': 145,
#          'capered': 1,
#          'droop': 3,
#          'autumn': 46,
#          'purchases': 9,
#          'seven': 132,
#          'sauerkraut': 1,
#          'forme': 1,
#          'roaring': 3,
#          'immune': 3,
#          'fanwise': 1,
#          'unwonted': 2,
#          'extremities': 26,
#          'dilly': 1,
#          '017': 1,
#          'ask': 251,
#          'unterkunft': 4,
#          'impenetrable': 5,
#          'trains': 21,
#          'insurrections': 3,
#          'semidark': 1,
#          'cloths': 5,
#          'pink': 27,
#          'kitchen': 19,
#          'desquamated': 1,
#          'pedantic': 2,
#          'newsboys': 1,
#          'predominance': 7,
#          'progressing': 4,
#          'valgum': 1,
#          'increased': 139,
#          'yelled': 8,
#          'avoid': 98,
#          '_bone_': 1,
#          'reconcile': 6,
#          'sudan': 1,
#          'deformity': 53,
#          'parched': 6,
#          'tilden': 6,
#          'bonds': 52,
#          'pieces': 28,
#          'thanked': 19,
#          'commendation': 3,
#          '_crural': 1,
#          'diffusing': 4,
#          'dissecting': 5,
#          'abolishing': 11,
#          'champions': 3,
#          'squire': 2,
#          'hit': 21,
#          'virginias': 1,
#          '_femoral_': 1,
#          'against': 660,
#          'immediately': 182,
#          'hans': 1,
#          'ulm': 12,
#          'arbitration': 27,
#          '_chronic_': 2,
#          'resemblances': 2,
#          'psychologist': 1,
#          'sternly': 42,
#          '1852': 9,
#          'brussels': 1,
#          'occurrence': 67,
#          'aqueducts': 1,
#          'haugwitz': 1,
#          '767': 1,
#          'foodstuffs': 1,
#          'entails': 3,
#          'absolute': 56,
#          'random': 8,
#          'gullies': 2,
#          'pronged': 1,
#          '609': 1,
#          '1766': 1,
#          'mackintosh': 1,
#          'wills': 13,
#          'beekeeper': 8,
#          'newburyport': 1,
#          'heirs': 8,
#          'promotes': 1,
#          'balances': 2,
#          'vacant': 10,
#          'revolution_': 13,
#          'pneumococcal': 7,
#          'moribund': 1,
#          'subscription': 5,
#          'confound': 6,
#          'scale': 45,
#          'slenderest': 1,
#          'hyoscin': 1,
#          'bookshop': 1,
#          'defending': 21,
#          'earning': 5,
#          'channel': 16,
#          '_minute': 1,
#          'revoked': 3,
#          'objectionable': 5,
#          'nominate': 5,
#          'thrombus_': 2,
#          'appraising': 1,
#          'captives': 1,
#          'cursed': 4,
#          'states_': 73,
#          'brunswick': 1,
#          'reciprocated': 1,
#          'ashes': 11,
#          'sympathetically': 4,
#          'courting': 2,
#          'gueules': 2,
#          'aback': 3,
#          'fluttered': 6,
#          'reharnessed': 1,
#          'filter': 4,
#          'parceling': 1,
#          'admonishingly': 1,
#          'rivalries': 2,
#          'chin': 30,
#          'contemptible': 9,
#          'actual': 64,
#          'precarious': 3,
#          'mules': 2,
#          'turkey': 20,
#          'blinked': 2,
#          '832': 1,
#          'mounted': 43,
#          'dura': 3,
#          'doses': 28,
#          'retailing': 1,
#          'orations': 4,
#          'unreasonable': 11,
#          'fee': 29,
#          'fateful': 10,
#          'clotilde': 1,
#          'englishmen': 3,
#          '191': 16,
#          'hole': 18,
#          'contended': 9,
#          'vassar': 3,
#          'glow': 22,
#          'apsherons': 4,
#          'horizontally': 1,
#          'hyoid': 3,
#          'gabions': 1,
#          'picturing': 7,
#          'caucuses': 3,
#          'circumstances': 107,
#          'investigate': 4,
#          'poses': 1,
#          'assertion': 5,
#          'holborn': 2,
#          'jest': 17,
#          'appreciating': 2,
#          'missile': 4,
#          'frontal': 11,
#          'traffic': 22,
#          'midfield': 1,
#          'counteract': 8,
#          'protectionists': 1,
#          'unusual': 32,
#          'lengthy': 3,
#          'wurttembergers': 2,
#          'professor': 8,
#          'spying': 1,
#          'bacchus': 1,
#          'product': 18,
#          'cows': 3,
#          'chessplayer': 1,
#          'dictated': 5,
#          'summer': 61,
#          'george': 150,
#          'expect': 61,
#          'formally': 6,
#          'waltz': 4,
#          'angiomata': 1,
#          'wilt': 2,
#          'missed': 28,
#          'versa': 5,
#          'batard': 1,
#          'brackets': 1,
#          'chivalrous': 3,
#          'probably': 147,
#          'aubert': 1,
#          'areolar': 2,
#          'weady': 2,
#          'alleviating': 2,
#          'uninterested': 1,
#          'morand': 5,
#          'selling': 16,
#          'congenial': 2,
#          'ruefully': 3,
#          '042': 1,
#          'legalized': 2,
#          'pm': 1,
#          'photographer': 1,
#          'excellent': 62,
#          'fashions': 1,
#          'pain': 299,
#          'positively': 13,
#          'dilates': 1,
#          'roughly': 9,
#          'texture': 6,
#          'bowler': 1,
#          'subsist': 1,
#          'dissented': 3,
#          'outing': 1,
#          'lateralis': 1,
#          'clears': 2,
#          'tempered': 7,
#          'bristly': 1,
#          '_industrial': 9,
#          'one': 3371,
#          'vibratory': 1,
#          'proptosis': 1,
#          'palliative': 4,
#          '1755': 3,
#          'arteriole': 1,
#          'description': 27,
#          'doctor': 183,
#          'tubal': 1,
#          'rates_': 1,
#          'lightly': 41,
#          'stimuli': 5,
#          'prohibitive': 3,
#          'mineral': 11,
#          'specification': 1,
#          'belt_': 1,
#          'lenient': 2,
#          'narrowing': 11,
#          'partially': 10,
#          'starring': 1,
#          'ponds': 6,
#          'gangrenous': 11,
#          'den': 17,
#          'straightening': 2,
#          'unreasoning': 9,
#          'eerie': 1,
#          'sit': 89,
#          'vas': 1,
#          'poisonous': 4,
#          'unimpeachable': 2,
#          'recurred': 9,
#          'ventral': 1,
#          'performing': 15,
#          'qualms': 1,
#          'retreating': 24,
#          'parisian': 3,
#          'deserters': 1,
#          'obtained': 75,
#          'accompli': 1,
#          'protects': 5,
#          'attracted': 36,
#          'former': 177,
#          '1881': 4,
#          'disturber': 1,
#          'eroded': 6,
#          'tidal': 1,
#          'contrive': 2,
#          'bouquet': 4,
#          'entrusted': 29,
#          '455ff': 1,
#          '557': 2,
#          '438': 16,
#          'banister': 1,
#          'dazzled': 4,
#          'ak': 3,
#          'contrasted': 5,
#          'triumphs': 4,
#          'news_': 1,
#          'humbled': 1,
#          'wabash': 1,
#          'trackless': 1,
#          'correction': 6,
#          'ward': 13,
#          'logical': 21,
#          'swing': 13,
#          'tenn': 3,
#          'forming': 62,
#          'closer': 35,
#          'pegs': 5,
#          'mischief': 6,
#          'thoughtful': 20,
#          'protest': 19,
#          '750': 3,
#          'actions': 77,
#          'roller': 1,
#          'moist': 61,
#          'producer': 1,
#          'saltykov': 3,
#          'necessarily': 31,
#          'cachets': 1,
#          'beeches': 12,
#          'intermediate': 10,
#          'postilions': 1,
#          'abroad': 54,
#          'false': 63,
#          'savor': 1,
#          'sodden': 12,
#          'soundly': 1,
#          'cuffs': 3,
#          'faro': 1,
#          'huts': 8,
#          'ankylosis_': 2,
#          'sclerosis_': 1,
#          'hustling': 1,
#          'flopped': 4,
#          '_red': 1,
#          'pomade': 1,
#          'flay': 2,
#          'chilblains': 6,
#          'census': 8,
#          'banner': 9,
#          'alaska': 12,
#          'greenwich': 1,
#          'supercilious': 1,
#          'scrawled': 5,
#          'drinking': 23,
#          'badly': 55,
#          'cowboys': 4,
#          'osteotomies': 3,
#          'unacknowledged': 1,
#          'epidemic': 1,
#          'superficially': 4,
#          '1794': 7,
#          '_traumatic': 6,
#          'strata': 1,
#          'coarseness': 1,
#          'falling': 54,
#          'implored': 8,
#          'suggestion': 24,
#          'approximates': 1,
#          'digesting': 1,
#          'polyglot': 1,
#          'frocks': 2,
#          'sluiceways': 1,
#          'term': 133,
#          'alexins': 1,
#          'tavel': 1,
#          'safes': 1,
#          'femoral': 37,
#          'natures': 2,
#          '633': 1,
#          'attracts': 5,
#          'novelty': 9,
#          'curtail': 1,
#          'abounding': 1,
#          '4000': 8,
#          '_varieties_': 10,
#          '_polygamy': 1,
#          'raymond': 1,
#          'coaled': 1,
#          'lineage': 1,
#          'flexors': 2,
#          'thinly': 1,
#          'reins': 20,
#          '_distal': 1,
#          'ceremonial': 4,
#          'rescinded': 1,
#          'torches': 1,
#          'toned': 4,
#          'administrations': 9,
#          'explosive': 1,
#          'wedding': 38,
#          'wrist_': 2,
#          'finland': 3,
#          'numbers': 65,
#          'dupuytren': 1,
#          'impetuosity': 3,
#          'forgetfulness': 6,
#          'sergey': 15,
#          'op': 1,
#          '494': 2,
#          'cushay': 1,
#          'demagogues': 2,
#          'chestnut': 15,
#          'keyboard': 2,
#          'chylorrhoea': 1,
#          'plums': 4,
#          'scold': 3,
#          'dreams': 16,
#          'fad': 1,
#          'comma': 2,
#          'wool': 40,
#          'vasili': 243,
#          '97': 13,
#          'resounded': 13,
#          'aldersgate': 1,
#          'bobtail': 1,
#          'lestrade': 38,
#          '641': 6,
#          'stuffy': 3,
#          'captive': 7,
#          'lifetime': 4,
#          'canals': 34,
#          '_antitoxic': 1,
#          'folly': 19,
#          'divest': 1,
#          '_pressure_': 2,
#          'relapsing': 12,
#          'sergeant': 40,
#          'seaman': 3,
#          'sort': 91,
#          'divide': 14,
#          'organism': 39,
#          'opposing': 20,
#          'dioxydiamido': 1,
#          'pool': 26,
#          'phalanges': 11,
#          'elderly': 33,
#          'oakshott': 7,
#          'bubo': 8,
#          'awoke': 19,
#          'disturbance': 42,
#          'camped': 1,
#          'itching': 7,
#          'deceptive': 2,
#          'thorough': 14,
#          'arching': 5,
#          'impassioned': 6,
#          'disclose': 7,
#          '213': 7,
#          'shutting': 2,
#          'endured': 9,
#          'chew': 1,
#          'alienated': 3,
#          'embezzlement': 2,
#          'pertinaciously': 1,
#          'comforts': 11,
#          'centimetres': 1,
#          'succor': 3,
#          'charmed': 4,
#          'shady': 3,
#          '_boils_': 1,
#          'freaks': 1,
#          'envoys': 2,
#          'straggling': 7,
#          'adamses': 1,
#          'rubbed': 32,
#          'endow': 1,
#          'respectable': 14,
#          'exudes': 4,
#          'boroughs': 3,
#          'tribes': 6,
#          'cubans': 5,
#          'alley': 5,
#          'suitably': 2,
#          'leniently': 1,
#          'equator': 1,
#          'ergotin': 1,
#          'viper': 2,
#          'reappearance': 3,
#          'bequest': 1,
#          '_risks_': 1,
#          'switch': 2,
#          '05': 1,
#          'escape': 96,
#          'cogently': 2,
#          'endangering': 1,
#          'flaws': 1,
#          '_chylo': 1,
#          'bulletin': 3,
#          'omental': 2,
#          'supination': 2,
#          '_exfoliation_': 1,
#          'fairbanks': 3,
#          'reverie': 7,
#          'rejoices': 2,
#          'porridge': 10,
#          'second': 277,
#          'displeasing': 1,
#          'shadowy': 1,
#          'rejected': 35,
#          'sol': 1,
#          'carpus': 2,
#          'iron': 77,
#          'smudge': 1,
#          'reimbursed': 1,
#          'coeur': 4,
#          'posed': 1,
#          'reenacted': 2,
#          'solemnity': 12,
#          'assailants': 1,
#          'regenerated': 6,
#          'herd': 15,
#          'genitals': 17,
#          '_dakota_': 1,
#          'buyers': 2,
#          'disintegrates': 2,
#          'accommodate': 4,
#          'jacobins': 3,
#          'raises': 2,
#          'justness': 1,
#          'mad': 36,
#          'hanover': 5,
#          'hotch': 1,
#          'sneering': 2,
#          'fibromatosis_': 4,
#          'yelling': 4,
#          'christian': 15,
#          'penza': 6,
#          'disobeying': 2,
#          'weaken': 7,
#          '66': 10,
#          'resistance': 47,
#          '99ff': 4,
#          'txt': 8,
#          'distension': 9,
#          'availing': 8,
#          'reward': 34,
#          'predominated': 2,
#          'lunch': 17,
#          '_villous': 1,
#          'grassland': 1,
#          'slavery': 208,
#          'deprive': 20,
#          'corresponded': 4,
#          'cadaver': 2,
#          'enterprises': 11,
#          'sparkle': 4,
#          'volatile': 4,
#          'fibrillation': 1,
#          'piedmont': 1,
#          '1826': 3,
#          'wealthiest': 1,
#          'diplomacy_': 1,
#          'anxiously': 20,
#          'kneeling': 8,
#          'bounce': 1,
#          'robert': 26,
#          'cargoes': 4,
#          'hancocks': 1,
#          '_eosinophilia_': 1,
#          'honoured': 1,
#          '_effusion': 1,
#          'bees': 24,
#          'lawbreaking': 1,
#          'ossification': 35,
#          'wednesday': 13,
#          'housemaid': 9,
#          'evolve': 3,
#          'gained': 45,
#          'prudence': 4,
#          'tradespeople': 2,
#          'specifically': 5,
#          'relieved': 25,
#          'idaho': 8,
#          'freemen': 4,
#          'swag': 1,
#          'waived': 1,
#          'essential': 92,
#          'desisted': 1,
#          'unsymmetrically': 1,
#          'overcoats': 7,
#          'churning': 1,
#          'manures': 1,
#          '202': 11,
#          'message': 46,
#          'haemophylics': 1,
#          'inquiries': 21,
#          'plumed': 2,
#          'pulled': 57,
#          'faneuils': 1,
#          'questioned': 23,
#          'greeted': 27,
#          'subserous': 1,
#          'reparations': 2,
#          'ergot': 4,
#          'synovia': 2,
#          'stepfather': 21,
#          'hafiz': 1,
#          'profoundly': 17,
#          'comfortably': 12,
#          '_puncture_': 1,
#          '_naso': 1,
#          '_lupus': 8,
#          'bolted': 3,
#          '1780': 7,
#          'management': 47,
#          'privacy': 3,
#          'retarded': 3,
#          'envelope': 26,
#          'framed': 12,
#          'compassionately': 3,
#          'aneurysms': 12,
#          'sedulously': 2,
#          '_the': 220,
#          'life': 868,
#          'figs': 12,
#          '1921': 9,
#          'wascal': 1,
#          'expedient': 8,
#          'disunion': 2,
#          'inventive': 1,
#          'ramrod': 4,
#          'adair': 1,
#          'markedly': 8,
#          'dissenters': 8,
#          'replaiting': 1,
#          'injuring': 6,
#          'important': 285,
#          'annular': 6,
#          'skinny': 2,
#          'alpha': 7,
#          '245': 9,
#          'redoubts': 2,
#          'broadened': 5,
#          'rags': 9,
#          'infringers': 1,
#          'eating': 24,
#          'bifida': 1,
#          'parallel': 17,
#          'auricle': 5,
#          'rapture': 14,
#          'suppose': 59,
#          'ambassador': 30,
#          'maidservants': 3,
#          'scarcity': 4,
#          'glint': 2,
#          'levee': 5,
#          'garrulously': 1,
#          'depends': 52,
#          'withdrew': 14,
#          'schooner': 2,
#          'condyle': 7,
#          'interpreter': 14,
#          ...})

# %%
# look at top 10 frequent words
all_words.most_common(10)
# Out:
# [('the', 79809),
#  ('of', 40024),
#  ('and', 38312),
#  ('to', 28765),
#  ('in', 22023),
#  ('a', 21124),
#  ('that', 12512),
#  ('he', 12401),
#  ('was', 11410),
#  ('it', 10681)]

# %%
def edits_one(word):
    "Create all edits that are one edit away from `word`."
    alphabets    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])                   for i in range(len(word) + 1)]
    deletes    = [left + right[1:]                       for left, right in splits if right]
    inserts    = [left + c + right                       for left, right in splits for c in alphabets]
    replaces   = [left + c + right[1:]                   for left, right in splits if right for c in alphabets]
    transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %%
def edits_two(word):
    "Create all edits that are two edits away from `word`."
    return (e2 for e1 in edits_one(word) for e2 in edits_one(e1))

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
def possible_corrections(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits_one(word)) or known(edits_two(word)) or [word])

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
print(len(set(edits_one("monney"))))
print(edits_one("monney"))
# Out:
# 336
# {'tonney', 'moneey', 'monnes', 'moeney', 'monnepy', 'monneb', 'monneyw', 'movney', 'monneo', 'bmonney', 'monrey', 'moonney', 'emonney', 'molnney', 'moiney', 'monnev', 'monndey', 'mwonney', 'monzney', 'moniey', 'monnky', 'xmonney', 'monncey', 'monneq', 'monneoy', 'monnejy', 'monnee', 'monnwey', 'mbonney', 'mponney', 'monneyg', 'aonney', 'rmonney', 'mvonney', 'mornney', 'montney', 'monniey', 'menney', 'nmonney', 'monpey', 'monuey', 'monneg', 'monnkey', 'monniy', 'monneiy', 'monnhy', 'moknney', 'mobnney', 'meonney', 'monkney', 'monny', 'monjey', 'monnzy', 'mfonney', 'onney', 'mopnney', 'mondney', 'monneyl', 'mcnney', 'mvnney', 'mohnney', 'monnec', 'wonney', 'monner', 'monnety', 'mnoney', 'monneay', 'monnevy', 'monneh', 'monnet', 'mmnney', 'moenney', 'moneney', 'monnex', 'monnea', 'monnyey', 'monnefy', 'monneyd', 'moncey', 'monfney', 'mtonney', 'ionney', 'modnney', 'monneby', 'monneya', 'uonney', 'monyney', 'wmonney', 'moqney', 'monhey', 'mpnney', 'monnuy', 'fonney', 'mronney', 'omonney', 'monkey', 'jonney', 'monnen', 'jmonney', 'monwney', 'monaey', 'moniney', 'mojney', 'mooney', 'monneyo', 'monnhey', 'monnley', 'mogney', 'mopney', 'monneym', 'mkonney', 'monuney', 'monnzey', 'monnpy', 'fmonney', 'monnye', 'monpney', 'monneyh', 'honney', 'monnfey', 'mlnney', 'motney', 'monvney', 'mjonney', 'hmonney', 'monnney', 'monnezy', 'umonney', 'maonney', 'monjney', 'monneyk', 'monnny', 'ymonney', 'monngy', 'mqonney', 'monnjey', 'mynney', 'mgnney', 'monvey', 'monsney', 'monnehy', 'monnpey', 'gonney', 'monneyp', 'amonney', 'monnrey', 'yonney', 'monnly', 'monnmy', 'monnry', 'bonney', 'momney', 'monnyy', 'mhonney', 'monneyy', 'mxonney', 'mojnney', 'monhney', 'monnuey', 'tmonney', 'konney', 'manney', 'mknney', 'mqnney', 'morney', 'mozney', 'monnxy', 'monlney', 'modney', 'movnney', 'monneu', 'mzonney', 'monneys', 'monneyu', 'monoey', 'monneyb', 'monnedy', 'monneuy', 'monnesy', 'cmonney', 'mionney', 'msnney', 'motnney', 'monyey', 'monnjy', 'myonney', 'monnoey', 'minney', 'monneye', 'monnemy', 'monnby', 'monbney', 'monney', 'monneyn', 'mocnney', 'monxey', 'mognney', 'monaney', 'monrney', 'mdnney', 'monnel', 'monntey', 'mosnney', 'moaney', 'monnvey', 'monnej', 'vonney', 'monnqey', 'monneyt', 'monnei', 'monnsey', 'monnfy', 'mlonney', 'ponney', 'mbnney', 'moznney', 'moncney', 'monzey', 'qonney', 'mounney', 'monne', 'monneyr', 'monneyz', 'mokney', 'monbey', 'mofnney', 'monneyx', 'monnqy', 'monnep', 'zmonney', 'mgonney', 'moqnney', 'monxney', 'mondey', 'monneyq', 'monnay', 'monned', 'lmonney', 'mnonney', 'monneky', 'monneey', 'mobney', 'monfey', 'monnoy', 'monnsy', 'monnez', 'xonney', 'momnney', 'money', 'monneny', 'monneyv', 'ronney', 'mosney', 'mouney', 'monnvy', 'munney', 'montey', 'moneny', 'monnbey', 'mongney', 'mownney', 'mhnney', 'mjnney', 'monnmey', 'mowney', 'monneyf', 'moynney', 'mmonney', 'monmney', 'monncy', 'gmonney', 'mohney', 'monneqy', 'donney', 'monnaey', 'mfnney', 'eonney', 'monnew', 'msonney', 'omnney', 'qmonney', 'monneyi', 'monnwy', 'mznney', 'kmonney', 'monnef', 'monnewy', 'monqney', 'monnery', 'sonney', 'moanney', 'mofney', 'monnty', 'monnek', 'monnxey', 'molney', 'monqey', 'moxney', 'monnely', 'monley', 'nonney', 'mconney', 'mongey', 'mocney', 'moyney', 'smonney', 'monmey', 'mononey', 'monneyj', 'dmonney', 'moinney', 'moxnney', 'monnecy', 'mdonney', 'mnnney', 'mwnney', 'oonney', 'monneyc', 'monwey', 'monnem', 'imonney', 'pmonney', 'monnexy', 'zonney', 'monndy', 'vmonney', 'monngey', 'muonney', 'lonney', 'monnegy', 'mxnney', 'mrnney', 'monsey', 'mnney', 'mtnney', 'conney'}

# %%
print(known(edits_one("monney")))
# Out:
# {'monkey', 'money'}

# %%
# Let's look at words that are two edits away
print(len(set(edits_two("monney"))))
print(known(edits_one("monney")))
# Out:
# 51013
# {'monkey', 'money'}

# %%
# Let's look at possible corrections of a word
print(possible_corrections("monney"))
# Out:
# {'monkey', 'money'}

# %%
# Let's look at probability of a word
print(prob("money"))
print(prob("monkey"))
# Out:
# 0.0002922233626303688
# 5.378344097491451e-06

# %%
def spell_check(word):
    "Print the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    if correct_word != word:
        return "Did you mean " + correct_word + "?"
    else:
        return "Correct spelling."

# %%
# test spell check
print(spell_check("Vat"))
# Out:
# Did you mean at?

# %%
def rectify(word):
    "return the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    return correct_word

# %%
rectify('lov')
# Out:
# 'love'

# %%
#!pip install pyspellchecker
#!pip install autocorrect
